# %% [markdown]
# # Lafla 1B Sıfırdan Eğitim
#
# Bu notebook hazır model ağırlığı yüklemez. Önce smoke eğitim çalıştırır.

# %%
# !pip install -q -r '/content/Lafla ai/requirements.txt'

# %%
# !python '/content/Lafla ai/colab/lafla_1b_sifirdan_egitim.py' --smoke
